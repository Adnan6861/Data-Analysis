# %%
import numpy as np
arr=np.linspace(1,50,10)
arr
# Out:
# array([ 1.        ,  6.44444444, 11.88888889, 17.33333333, 22.77777778,
#        28.22222222, 33.66666667, 39.11111111, 44.55555556, 50.        ])

# %% [markdown]
# import n

# %%
arr1=np.random.rand(2,2,3)
arr1
# Out:
# array([[[0.3547642 , 0.81093449, 0.67882142],
#         [0.32448897, 0.5717654 , 0.13627358]],
#
#        [[0.09403812, 0.65917014, 0.00736873],
#         [0.55398685, 0.16469006, 0.5517405 ]]])
