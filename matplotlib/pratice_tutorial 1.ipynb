# %% [markdown]
# ## Welcome to Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Type
# 1-- Numerical
#
# 2-- categorical
#
# @ --graph on signal columns are also called univarient Graph
#
# @--graph on two Columns are also Called BIvarient Graph
#
# @-- Graph More Than two Column also Called MultiColumn Graph
#
# Hint ** Remember the Type of Data and
#
# Varient of Data **

# %% [markdown]
# ## Start 2D line Plot
#
# --used For Bivariate Analysis
#
# --apply only Two Columns of Entire data
#
# --apply when Two Cloumn are Numberical ...
#
# -- Best Case is When one is Numerical and other in categorical
#
# *** Plot on Time-Series Data **
# -Stock
# -Revene
# -Covid Time
#
# ---categorical on x-axis means First Writen other in Numeric is y-axis

# %%
shop=[1000,2000,3000,2500]
price=[2007,2008,2009,2010]
plt.plot(shop,price)

# %% [markdown]
# ## Import Data-Set

# %%
data1=pd.read_csv('data_set/sharma-kohli.csv')
plt.plot(data1['index'],data1['RG Sharma'])
print(data1)
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
# Check Side By Side ...
# Curve of two Entity on Same Graph
# Both Writen in Each other
plt.plot(data1['index'],data1['RG Sharma'])
plt.plot(data1['index'],data1['V Kohli'])
# We can also Add title to make informative For the other
plt.title('IPL Babar Vs Kohali')
# Out:
# Text(0.5, 1.0, 'IPL Babar Vs Kohali')
