# %% [markdown]
# # NetFlix Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt
import seaborn as sns

# %%
n_file=pd.read_csv(r'projects\Netflix_Project\mymoviedb.csv')
# Out:
#   Cell In[2], line 1
#     n_file=pd.read_csv('projects\Netflix_Project\mymoviedb.csv')
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 8-9: malformed \N character escape
